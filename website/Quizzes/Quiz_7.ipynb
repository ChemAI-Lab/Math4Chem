# %% [markdown]
# # Quiz 7
#
# Please answer all the questions **only** in the sections marked with:
# `# Write your code here` and `Write your answer here`
#
# ---
# **Name:**
# **Student Number:**
# **Deadline:** 18 November 2025, 2:20 PM
#
# ---

# %% [markdown]
# 1. For a 2x2 matrix A, the characteristic polynomial is:
#
# $p_A(λ) = det(A - λI) = λ² - tr(A)λ + det(A)$
#
# Cayley-Hamilton Theorem states that any sqaure matrix satisfies its own characteristic equation:
#
# $p_A(A) = A² - tr(A)A + det(A)I = 0$

# %% [markdown]
# Create a python function that implements the Cayley-Hamilton Theorem and test for any square matrix.

# %%
#Your code here.

# %% [markdown]
# 2. Given system of equations:
#
# $2x_1 + 4x_3 + 4x_4 = 14$
#
# $-x_1 - x_3 = -3$
#
# $-3x_1 + 6x_4 = 3$
#
# First, write and print the augmented matrix $A$ of this system. Then, try to solve the system using Gaussian Elimination, implementing each row operation as a new function. For example,

# %%
def add_row(A,k,i,j):
    "row j <- k times row i added to row j in matrix A."

# %%
#Your code here

# %% [markdown]
# Can you actually solve the system ? If not explain why.
