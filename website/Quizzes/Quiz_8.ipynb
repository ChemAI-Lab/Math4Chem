# %% [markdown]
# # Quiz 8
#
# Please answer all the questions **only** in the sections marked with:
# `# Write your code here` and `Write your answer here`
#
# ---
# **Name:**
# **Student Number:**
# **Deadline:** 25 November 2025, 2:20 PM
#
# ---

# %% [markdown]
# 1. Manual calculation approach (NumPy)
#
# For a simple linear regression (one predictor variable), you can manually calculate the regression parameters using $\textbf{NumPy}$. This involves first
#
# ---
#
# calculating the mean of the independent and dependent variables. We then compute the slope ($B_1$):
#
# $
# B_1 = \frac{\sum(x - \overline{x})(y - \overline{y})}{\sum(x - \overline{x})^2}
# $
#
# Once we have the slope, we can determine the intercept ($B_0$):
#
# $
# B_0 = \overline{y} - B_1\overline{x}
# $

# %% [markdown]
# Given the sample data:

# %%
import numpy as np
# Sample data
x = np.array([0, 1, 2, 3, 4, 5, 6])
y = np.array([1, 3, 2, 5, 7, 8, 8])

# %% [markdown]
# Do the manual calculation of the linear regression. First compute the means.

# %%
# Compute means

# %% [markdown]
# Then compute the slope and the intercept. (Print both values)

# %%
# Compute slope (B1)


# Compute intercept (B0)

# %% [markdown]
# Then print the predicted values.

# %%
# Predicting values

# %% [markdown]
# Calculate the L2-norm.

# %%
# L2-norm

# %% [markdown]
# Plot the data and the linear fit.

# %%
# Plot

# %% [markdown]
# NumPy also provides a built-in function `np.polyfit()`, which can perform linear regression for you with just one line of code. Compare the results of `np.polyfit()` and your manual calculation.

# %%
# Comparisson

# %% [markdown]
# 2. Multiple linear regression in Python
#
# Multiple linear regression extends the concept of simple linear regression to model relationships between a dependent variable and multiple independent variables.
#
# To perform multiple linear regression in Python, we typically use matrix algebra to calculate the coefficients that minimize the residual sum of squares.
# $
# \textbf{w} = (X^T X)^{-1} X^T Y
# $
# **bold text**
# (Equation 46 of the linear regression notes)

# %% [markdown]
# Given the sample data:

# %%
import numpy as np

# Sample data: two predictors and one dependent variable
X = np.array([[1, 1], [1, 2], [2, 2], [2, 3]])  # Independent variables
y = np.array([6, 8, 9, 11])  # Dependent variable

# %% [markdown]
# Calculate the $\textbf{w}$ coeficients.

# %%
# Your code here.

# %% [markdown]
# Make the predictions. $X @ w$ (Check the format of X in this case to account for the interception)

# %%
# Your code here.

# %% [markdown]
# Using a machine learning library (scikit-learn). It offers a simple and efficient way to perform linear regression using the LinearRegression class.

# %% [markdown]
# Compare the intercept and the coeficients with scikit-learn using:

# %%
# Compare results
from sklearn.linear_model import LinearRegression
